# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
retina = cv2.imread('/Users/teguhsatya/Dev/T/dataset/Fundus_Scanes_Sorted/Train/Glaucoma_Positive/182.jpg')
retina = cv2.cvtColor(retina, cv2.COLOR_BGR2RGB)
plt.imshow(retina)

# %%
scale_percent = 60 # percent of original size
width = int(retina.shape[1] * scale_percent / 100)
height = int(retina.shape[0] * scale_percent / 100)
dim = (width, height)
  
# resize image
resized = cv2.resize(retina, dim, interpolation = cv2.INTER_AREA)

# %%
plt.imshow(resized)

# %%
cropped = retina[400:1400, 500:2500]
plt.imshow(cropped)

# %%
plt.imshow((hsv[:,:,2]/50), 'gray')

# %%
hsv = cv2.cvtColor(cropped, cv2.COLOR_RGB2HSV)

# %%
plt.imshow(hsv[:,:,2], 'gray')

# %%
blur = cv2.medianBlur(hsv[:,:,1], 45)
plt.imshow(blur, 'gray')

# %%
ret,thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV)

# %%
plt.imshow(thresh, 'gray')

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
x,y,w,h = cv2.boundingRect(contours)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 x,y,w,h = cv2.boundingRect(contours)
#
# error: OpenCV(4.6.0) :-1: error: (-5:Bad argument) in function 'boundingRect'
# > Overload resolution failed:
# >  - array is not a numerical tuple
# >  - Expected Ptr<cv::UMat> for argument 'array'
