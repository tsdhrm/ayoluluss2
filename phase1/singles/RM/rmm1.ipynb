# %% [markdown]
# # RM Mark 1: Morph

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
rm = cv2.imread('/Users/teguhsatya/Dev/segeralulus/samples/s_rm.png')
rm_rgb = cv2.cvtColor(rm, cv2.COLOR_BGR2RGB)
rm_res = cv2.resize(rm_rgb, (int(rm_rgb.shape[1]*50/100), int(rm_rgb.shape[0]*50/100)), cv2.INTER_AREA)

# %%
rm_res.shape
# Out:
# (252, 252, 3)

# %%
plt.imshow(rm_res)

# %%
plt.imshow(rm_res[:,:,2], cmap='gray')

# %%
plt.imshow(rm_res)

# %%
hsv_rm = cv2.cvtColor(rm_res, cv2.COLOR_RGB2HSV)

# %%
shsv = hsv_rm[:,:,1]

# %%
plt.imshow(shsv, cmap='gray')

# %%
shsv_blur = cv2.medianBlur(shsv.copy(), 13)

# %%
plt.imshow(shsv_blur, cmap='gray')
